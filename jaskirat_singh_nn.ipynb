# %% [markdown]
# # **`Melanoma Detection Assignment`**

# %% [markdown]
# ## Problem statement

# %% [markdown]
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import math
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers.experimental.preprocessing import Rescaling, RandomFlip, RandomRotation, RandomZoom, RandomContrast
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, Dropout, Activation, MaxPool2D, concatenate, BatchNormalization
from tensorflow.keras import optimizers, losses, metrics

# %% [markdown]
# ## 1. Data Reading/Understanding

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %%
# Defining the path for train and test images

train_folder_path = "Train"
test_folder_path = "Test"

data_dir_train = pathlib.Path(train_folder_path)
data_dir_test = pathlib.Path(test_folder_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print("\033[1mTraining\033[0m dataset contains \033[1m{0}\033[0m images".format(image_count_train))
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print("\033[1mTest\033[0m dataset contains \033[1m{0}\033[0m images".format(image_count_test))
# Out:
# Training dataset contains 2239 images
# Test dataset contains 118 images

# %% [markdown]
# ## 2. Dataset Creation
#
# We will be creating ***train*** & ***validation*** dataset from the ***train directory***.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Creating a dataset
#
# Defining some parameters for the loader:

# %%
batch_size = 32 # batch size for training

# %% [markdown]
# Using ***seed=123*** while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory

# %%
seed = 123  # Seed to be used for dataset creation

# %% [markdown]
# Parameters for ***resizing*** the images

# %%
img_height = 180
img_width = 180

# %% [markdown]
# Using ***80%*** of the images for ***training***, and ***20%*** for ***validation***.

# %%
validation_split = 0.2  # Train and validation split

# %% [markdown]
# Removing any augmentor images from previous runs

# %%
import glob, os, shutil
dirs = data_dir_train.glob("*/output")
for dir in dirs:
    shutil.rmtree(dir)

# %%
## Creating our train dataset here
## Resizing train images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, 
                                                           batch_size=batch_size,
                                                           image_size=(img_height, img_width),
                                                           seed=seed,
                                                           validation_split=validation_split,
                                                           subset='training')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# 2022-07-20 21:54:48.260540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.284216: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.284360: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.285312: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-20 21:54:48.285569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.285691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.285784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.618885: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.619036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.619147: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 21:54:48.619237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7394 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
## Creating our validation dataset here 
## Resizing validation images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, 
                                                           batch_size=batch_size,
                                                           image_size=(img_height, img_width),
                                                           seed=seed,
                                                           validation_split=validation_split,
                                                           subset='validation')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
print("We got \033[1mTraining Dataset\033[0m containing \033[1m{0} images\033[0m".format(math.ceil(image_count_train*(1-validation_split))))
print("We got \033[1mValidation Dataset\033[0m containing \033[1m{0} images\033[0m".format(math.floor(image_count_train*(validation_split))))
# Out:
# We got Training Dataset containing 1792 images
# We got Validation Dataset containing 447 images

# %%
# Listing out all the classes of skin cancer and storing them in a list. 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
class_count = len(class_names)
print("We got \033[1m{0} classes\033[0m which our model will be classifying".format(class_count))
# Out:
# We got 9 classes which our model will be classifying

# %% [markdown]
# ## 3. Data Visualization
#
# #### Visualizing one instance of all the nine classes present in the dataset

# %%
plt.figure(figsize=(20, 15))  # Setting canvas size so we can observe all images easily
for images, labels in train_ds.take(1):
    for i,label in enumerate(class_names):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(label)
        plt.axis('off')

# %% [markdown]
# ### Checking shapes of tensors

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# As seen above the `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# ## 4. Model Building and Training - Model 1 - Base CNN Model with raw data
#
# ### Creating first CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers, and each layer is followed by a ***Maxpooling layer***, downsizing the dimensions
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %% [markdown]
# ### Optimizing datasets for cache and prefetch

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Defining input shape
input_shape = (img_height, img_width, 3)

# %%
model1 = Sequential()

model1.add(Rescaling(1./255, input_shape = input_shape))

model1.add(Conv2D(32, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))
model1.add(Conv2D(32, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Conv2D(64, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))
model1.add(Conv2D(64, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Conv2D(128, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))
model1.add(Conv2D(128, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Flatten())
model1.add(Dense(1000, activation='relu'))
model1.add(Dense(class_count, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model1.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 128)         147584
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1000)              513000
#
#  dense_1 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 809,017
# Trainable params: 809,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***20 epochs***

# %%
### %%time
model1_epochs = 20
history1 = model1.fit(train_ds,
                      validation_data=val_ds,
                      epochs=model1_epochs)

# %% [markdown]
# ### Visualizing training results

# %%
def visualizeResults(history, train_epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(train_epochs)

    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    return acc, val_acc
acc1, val_acc1 = visualizeResults(history1, model1_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model1_epochs,max(acc1)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model1_epochs,max(val_acc1)*100))
# Out:
# Train Accuracy after 20 epochs: 62.95
# Validation Accuracy after 20 epochs: 55.70

# %% [markdown]
# ### Findings
#
# - Observing above graphs we can conclude that model ***Overfits*** to some degree, as the training accuracy is about ***63%*** and validation accuracy is approximately ***55.7%***.
# - The mode seems to be learning well but is overfitting as there is ***8%*** difference in training and validation.
# - It could be due to class imbalance or model is just learning noise. We need to add more data for it to generalise better. We might also use dropout to prevent noise leaking into model.

# %% [markdown]
# ## 5. Data Augmentation
#
# - As the model is overfitting, we will use data augmentation strategy to generate more data to improve the model performance as mentioned in findings of Model 1.
# - Since the classification is not constrained by the lighting or orientation or size of the infected area following data augmentation strategies can used.
#     - Flips (Vertical and Horizontal)
#     - Rotation (Various degrees)
#     - Zooming
#     - Contrast variation
# - We will be using random transformations package for this.

# %%
augument_data = Sequential([
    RandomFlip('horizontal_and_vertical'),
    RandomRotation((-0.1, 0.1)), 
    RandomZoom(0.2),
    RandomContrast(0.05)])

# %% [markdown]
# #### Visualizing how our augmentation strategy works for one instance of training image

# %%
plt.figure(figsize=(16, 8))
for images, labels in train_ds.take(1):
    image = images[0]
    label = tf.keras.backend.get_value(labels[0])
    
    ax = plt.subplot(1, 2, 1)
    plt.imshow(image.numpy().astype('uint8'))
    plt.title("Actual Image: " + class_names[label])

    ax = plt.subplot(1, 2, 2)
    image_aug = augument_data(tf.cast(image, tf.float32))
    plt.imshow(image_aug.numpy().astype('uint8'))
    plt.title("Augmented Image: " + class_names[label])
    
    plt.show()
    break

# %% [markdown]
# ## 6. Model Building and Training - Model 2 - Base CNN Model with dropout and Data Augumentation
#
# ### Creating second CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Data Augumentation layer
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers, and each layer is followed by a ***Maxpooling layer*** and a ***Dropout layer***
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %%
model2 = Sequential()

model2.add(Rescaling(1./255, input_shape = input_shape))

model2.add(augument_data)


model2.add(Conv2D(32, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Conv2D(32, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Conv2D(64, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Conv2D(64, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))


model2.add(Conv2D(128, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Conv2D(128, 3, padding='same',  activation='relu'))
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Flatten())
model2.add(Dense(1000, activation='relu'))
model2.add(Dense(class_count, activation='softmax'))
# Out:
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model2.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (180, 180, 3)             0
#
#  conv2d_7 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 90, 90, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 90, 90, 32)        9248
#
#  max_pooling2d_8 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 22, 22, 64)        36928
#
#  max_pooling2d_10 (MaxPoolin  (None, 11, 11, 64)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 11, 11, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 5, 5, 128)         0
#
#  conv2d_12 (Conv2D)          (None, 5, 5, 128)         147584
#
#  max_pooling2d_12 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1000)              513000
#
#  dense_3 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 809,017
# Trainable params: 809,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***20 epochs***

# %% [markdown]
# ### %%time
# model2_epochs = 20
# history2 = model2.fit(train_ds,
#                       validation_data=val_ds,
#                       epochs=model2_epochs)

# %% [markdown]
# ### Visualizing the results

# %%
acc2, val_acc2 = visualizeResults(history2, model2_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model2_epochs,max(acc2)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model2_epochs,max(val_acc2)*100))
# Out:
# Train Accuracy after 20 epochs: 53.57
# Validation Accuracy after 20 epochs: 49.66

# %% [markdown]
# ### Findings
#
# - The training accuracy is about ***53.5%*** and validation accuracy is approximately ***49.66%*** indicating that dropouts and data augumentation has helped closing the gap and preventing overfits.
# - Both validation and training accuracy went down but the gap closed means we were able to remove some level of overfitting.
# - Since training accuracy itself is dropped that means its has started to underfit, hence adding more data should help in improving the model.

# %% [markdown]
# ## 7. Examine Class Distribution in Training data set
#
# Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
class_distribution = {}
for cls in class_names:
    path = pathlib.Path(os.path.join(train_folder_path, cls))
    count = len(list(path.glob('*.jpg')))
    class_distribution[cls]=count
print(class_distribution)

plt.figure(figsize=(15, 6))
plt.bar(list(class_distribution.keys()), list(class_distribution.values()))
plt.title("Class distribution in training data")
plt.xticks(rotation = 45, ha = 'right');
# Out:
# {'actinic keratosis': 114, 'basal cell carcinoma': 376, 'dermatofibroma': 95, 'melanoma': 438, 'nevus': 357, 'pigmented benign keratosis': 462, 'seborrheic keratosis': 77, 'squamous cell carcinoma': 181, 'vascular lesion': 139}

# %% [markdown]
# ### Findings
#
# - Class 6(seborrheic keratosis) have least samples of all i.e. 77
# - Class 5(pigmented benign keratosis) dominate in terms of proportionate number of samples  i.e. 462
# - Dataset is quite imbalanced

# %% [markdown]
# ## 8. Handling class imbalances
#
# - It is improtant to have class balance for better infering the performance of the model.
# - Having good amount of data, helps the model to learn the useful features and improve the prediction power of the model.
# - We will use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.
# - This will help us tackle the class imbalance issue and increase input data volume for better modelling.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /home/jaskirat/miniconda3/lib/python3.8/site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.11.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (1.23.1)
# Requirement already satisfied: future>=0.16.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (0.18.2)
# Requirement already satisfied: tqdm>=4.9.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (4.63.0)
# Requirement already satisfied: Pillow>=5.2.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (9.2.0)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=train_folder_path
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + '/' + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF61482C1F0>: 100%|██████████| 500/500 [00:02<00:00, 219.12 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF6147DA970>: 100%|██████████| 500/500 [00:02<00:00, 216.35 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF6148A4070>: 100%|██████████| 500/500 [00:02<00:00, 212.46 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF614852A30>: 100%|██████████| 500/500 [00:11<00:00, 43.59 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=962x723 at 0x7FF614856CD0>: 100%|██████████| 500/500 [00:11<00:00, 45.39 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF614782D00>: 100%|██████████| 500/500 [00:02<00:00, 216.05 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF2FD8D3430>: 100%|██████████| 500/500 [00:05<00:00, 94.18 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF614855250>: 100%|██████████| 500/500 [00:02<00:00, 218.03 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF6147FDBE0>: 100%|██████████| 500/500 [00:02<00:00, 209.23 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
## path of individual images from new data

path_list_new = [x for x in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
len(path_list_new)
# Out:
# 4500

# %%
## classnames for individual images from new data

lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
len(lesion_list_new)
# Out:
# 4500

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
new_df = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])

# %%
new_df['Label'].value_counts()
# Out:
# squamous cell carcinoma       500
# pigmented benign keratosis    500
# nevus                         500
# vascular lesion               500
# melanoma                      500
# actinic keratosis             500
# seborrheic keratosis          500
# dermatofibroma                500
# basal cell carcinoma          500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ## 9. Model Building and Training - Model 3 - Base CNN Model with Balanced Class Data

# %% [markdown]
# ### Creating augmented training dataset

# %%
train_ds_aug = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=seed,
  validation_split = validation_split,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### Creating augumented validation dataset

# %%
val_ds_aug = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=seed,
  validation_split = validation_split,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ### Creating third CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers,and each layer is followed by a ***Batch Normalization layer***, a ***Maxpooling layer*** and a ***Dropout layer***
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %%
model3 = Sequential()

model3.add(Rescaling(1./255, input_shape = input_shape))

model3.add(Conv2D(32, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Conv2D(32, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Conv2D(64, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Conv2D(64, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Conv2D(128, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Conv2D(128, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model3.add(Dropout(0.25))

model3.add(Flatten())
model3.add(Dense(1000, activation='relu'))
model3.add(Dense(class_count, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model3.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_13 (Conv2D)          (None, 180, 180, 32)      896
#
#  batch_normalization (BatchN  (None, 180, 180, 32)     128
#  ormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 90, 90, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 90, 90, 32)       128
#  hNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 45, 45, 32)       0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 45, 45, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 45, 45, 64)       256
#  hNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_16 (Conv2D)          (None, 22, 22, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 22, 22, 64)       256
#  hNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 11, 11, 64)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 11, 11, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 11, 11, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 11, 11, 128)      512
#  hNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 5, 5, 128)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 5, 5, 128)         0
#
#  conv2d_18 (Conv2D)          (None, 5, 5, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 5, 5, 128)        512
#  hNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 2, 2, 128)         0
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 1000)              513000
#
#  dense_5 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 810,809
# Trainable params: 809,913
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***30 epochs***

# %%
# %%time
model3_epochs = 30
history3 = model3.fit(train_ds_aug,
                      validation_data=val_ds_aug,
                      epochs=model3_epochs)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 10s 53ms/step - loss: 1.8242 - accuracy: 0.3783 - val_loss: 3.2971 - val_accuracy: 0.1351
# Epoch 2/30
# 169/169 [==============================] - 9s 51ms/step - loss: 1.3635 - accuracy: 0.4844 - val_loss: 3.4769 - val_accuracy: 0.1648
# Epoch 3/30
# 169/169 [==============================] - 9s 51ms/step - loss: 1.1941 - accuracy: 0.5484 - val_loss: 2.6685 - val_accuracy: 0.2056
# Epoch 4/30
# 169/169 [==============================] - 9s 51ms/step - loss: 1.0870 - accuracy: 0.5874 - val_loss: 1.7572 - val_accuracy: 0.4165
# Epoch 5/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.9806 - accuracy: 0.6278 - val_loss: 1.2954 - val_accuracy: 0.5382
# Epoch 6/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.8721 - accuracy: 0.6704 - val_loss: 1.0909 - val_accuracy: 0.5895
# Epoch 7/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.7697 - accuracy: 0.7060 - val_loss: 1.8909 - val_accuracy: 0.4113
# Epoch 8/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.7213 - accuracy: 0.7239 - val_loss: 1.9132 - val_accuracy: 0.4707
# Epoch 9/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.6597 - accuracy: 0.7480 - val_loss: 1.1937 - val_accuracy: 0.6184
# Epoch 10/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.6072 - accuracy: 0.7676 - val_loss: 1.5992 - val_accuracy: 0.5620
# Epoch 11/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.5337 - accuracy: 0.7982 - val_loss: 0.9379 - val_accuracy: 0.6912
# Epoch 12/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.5136 - accuracy: 0.7962 - val_loss: 1.3672 - val_accuracy: 0.5954
# Epoch 13/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.4798 - accuracy: 0.8129 - val_loss: 1.3799 - val_accuracy: 0.5754
# Epoch 14/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.4483 - accuracy: 0.8297 - val_loss: 0.6563 - val_accuracy: 0.7647
# Epoch 15/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.4221 - accuracy: 0.8349 - val_loss: 0.5067 - val_accuracy: 0.8099
# Epoch 16/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.3936 - accuracy: 0.8531 - val_loss: 0.7869 - val_accuracy: 0.7372
# Epoch 17/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3616 - accuracy: 0.8605 - val_loss: 1.2604 - val_accuracy: 0.6102
# Epoch 18/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3310 - accuracy: 0.8704 - val_loss: 1.2212 - val_accuracy: 0.6496
# Epoch 19/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.3282 - accuracy: 0.8752 - val_loss: 0.8846 - val_accuracy: 0.7134
# Epoch 20/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3330 - accuracy: 0.8757 - val_loss: 1.5476 - val_accuracy: 0.5345
# Epoch 21/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3037 - accuracy: 0.8845 - val_loss: 1.1215 - val_accuracy: 0.6808
# Epoch 22/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.2969 - accuracy: 0.8848 - val_loss: 0.8562 - val_accuracy: 0.7171
# Epoch 23/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3102 - accuracy: 0.8811 - val_loss: 1.2145 - val_accuracy: 0.6904
# Epoch 24/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.3203 - accuracy: 0.8772 - val_loss: 1.4600 - val_accuracy: 0.5924
# Epoch 25/30
# 169/169 [==============================] - 9s 51ms/step - loss: 0.2761 - accuracy: 0.8921 - val_loss: 2.1789 - val_accuracy: 0.5011
# Epoch 26/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.2713 - accuracy: 0.8943 - val_loss: 0.3849 - val_accuracy: 0.8731
# Epoch 27/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.2359 - accuracy: 0.9041 - val_loss: 0.8770 - val_accuracy: 0.7179
# Epoch 28/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.2639 - accuracy: 0.8935 - val_loss: 0.9317 - val_accuracy: 0.7238
# Epoch 29/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.2347 - accuracy: 0.9071 - val_loss: 0.4890 - val_accuracy: 0.8389
# Epoch 30/30
# 169/169 [==============================] - 9s 50ms/step - loss: 0.2425 - accuracy: 0.9021 - val_loss: 0.4173 - val_accuracy: 0.8708
# CPU times: user 15min 9s, sys: 22.4 s, total: 15min 31s
# Wall time: 4min 27s

# %% [markdown]
# ### Visualizing the results

# %%
acc3, val_acc3 = visualizeResults(history3, model3_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model3_epochs,max(acc3)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model3_epochs,max(val_acc3)*100))
# Out:
# Train Accuracy after 30 epochs: 90.71
# Validation Accuracy after 30 epochs: 87.31

# %% [markdown]
# ### Findings
#
# - With class rebalance and more epochs we got tremendous improvements.
# - The *** training and validation accuracy*** to has got to ***decent levels***.
# - We can add more data and layers to further improve the performance.
