# %% [markdown]
# # **`Melanoma Detection Assignment`**

# %% [markdown]
# ## Problem statement

# %% [markdown]
# To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import math
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers.experimental.preprocessing import Rescaling, RandomFlip, RandomRotation, RandomZoom, RandomContrast
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, Dropout, Activation, MaxPool2D, concatenate, BatchNormalization
from tensorflow.keras import optimizers, losses, metrics

# %% [markdown]
# ## 1. Data Reading/Understanding

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
## If you are using the data by mounting the google drive, use the following :
## from google.colab import drive
## drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %%
# Defining the path for train and test images

train_folder_path = "Train"
test_folder_path = "Test"

data_dir_train = pathlib.Path(train_folder_path)
data_dir_test = pathlib.Path(test_folder_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print("\033[1mTraining\033[0m dataset contains \033[1m{0}\033[0m images".format(image_count_train))
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print("\033[1mTest\033[0m dataset contains \033[1m{0}\033[0m images".format(image_count_test))
# Out:
# Training dataset contains 2239 images
# Test dataset contains 118 images

# %% [markdown]
# ## 2. Dataset Creation
#
# We will be creating ***train*** & ***validation*** dataset from the ***train directory***.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Creating a dataset
#
# Defining some parameters for the loader:

# %%
batch_size = 32 # batch size for training

# %% [markdown]
# Using ***seed=123*** while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory

# %%
seed = 123  # Seed to be used for dataset creation

# %% [markdown]
# Parameters for ***resizing*** the images

# %%
img_height = 180
img_width = 180

# %% [markdown]
# Using ***80%*** of the images for ***training***, and ***20%*** for ***validation***.

# %%
validation_split = 0.2  # Train and validation split

# %% [markdown]
# Removing any augmentor images from previous runs

# %%
import glob, os, shutil
dirs = data_dir_train.glob("*/output")
for dir in dirs:
    shutil.rmtree(dir)

# %%
## Creating our train dataset here
## Resizing train images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, 
                                                           batch_size=batch_size,
                                                           image_size=(img_height, img_width),
                                                           seed=seed,
                                                           validation_split=validation_split,
                                                           subset='training')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# 2022-07-20 20:46:47.089825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.115425: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.115574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.116210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-20 20:46:47.116474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.116580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.116671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.450864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.451017: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.451119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-20 20:46:47.451200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7394 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1070, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
## Creating our validation dataset here 
## Resizing validation images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, 
                                                           batch_size=batch_size,
                                                           image_size=(img_height, img_width),
                                                           seed=seed,
                                                           validation_split=validation_split,
                                                           subset='validation')
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
print("We got \033[1mTraining Dataset\033[0m containing \033[1m{0} images\033[0m".format(math.ceil(image_count_train*(1-validation_split))))
print("We got \033[1mValidation Dataset\033[0m containing \033[1m{0} images\033[0m".format(math.floor(image_count_train*(validation_split))))
# Out:
# We got Training Dataset containing 1792 images
# We got Validation Dataset containing 447 images

# %%
# Listing out all the classes of skin cancer and storing them in a list. 
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
class_count = len(class_names)
print("We got \033[1m{0} classes\033[0m which our model will be classifying".format(class_count))
# Out:
# We got 9 classes which our model will be classifying

# %% [markdown]
# ## 3. Data Visualization
#
# #### Visualizing one instance of all the nine classes present in the dataset

# %%
plt.figure(figsize=(20, 15))  # Setting canvas size so we can observe all images easily
for images, labels in train_ds.take(1):
    for i,label in enumerate(class_names):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(label)
        plt.axis('off')

# %% [markdown]
# ### Checking shapes of tensors

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# As seen above the `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# ## 4. Model Building and Training - Model 1 - Base CNN Model with raw data
#
# ### Creating first CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers, followed by a ***Maxpooling layer***, downsizing the dimensions
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %% [markdown]
# ### Optimizing datasets for cache and prefetch

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# Defining input shape
input_shape = (img_height, img_width, 3)

# %%
model1 = Sequential()

model1.add(Rescaling(1./255, input_shape = input_shape))

model1.add(Conv2D(32, 3, padding='same',  activation='relu'))
model1.add(Conv2D(32, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Conv2D(64, 3, padding='same',  activation='relu'))
model1.add(Conv2D(64, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Conv2D(128, 3, padding='same',  activation='relu'))
model1.add(Conv2D(128, 3, padding='same',  activation='relu'))
model1.add(MaxPool2D(2,2))

model1.add(Flatten())
model1.add(Dense(1000, activation='relu'))
model1.add(Dense(class_count, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model1.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 45, 45, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 61952)             0
#
#  dense (Dense)               (None, 1000)              61953000
#
#  dense_1 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 62,249,017
# Trainable params: 62,249,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***20 epochs***

# %%
# %%time
model1_epochs = 20
history1 = model1.fit(train_ds,
                      validation_data=val_ds,
                      epochs=model1_epochs)
# Out:
# Epoch 1/20
# 2022-07-20 20:46:52.700075: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-07-20 20:46:52.984351: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 56/56 [==============================] - 10s 109ms/step - loss: 2.1200 - accuracy: 0.1920 - val_loss: 2.0410 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 5s 94ms/step - loss: 2.0191 - accuracy: 0.2227 - val_loss: 2.0446 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 5s 94ms/step - loss: 2.0255 - accuracy: 0.2003 - val_loss: 1.9879 - val_accuracy: 0.2237
# Epoch 4/20
# 56/56 [==============================] - 5s 94ms/step - loss: 2.0046 - accuracy: 0.2148 - val_loss: 2.0426 - val_accuracy: 0.2036
# Epoch 5/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.9842 - accuracy: 0.2081 - val_loss: 1.9691 - val_accuracy: 0.2394
# Epoch 6/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.9630 - accuracy: 0.2288 - val_loss: 1.9833 - val_accuracy: 0.2685
# Epoch 7/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.9244 - accuracy: 0.2746 - val_loss: 1.7939 - val_accuracy: 0.3781
# Epoch 8/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.7673 - accuracy: 0.3795 - val_loss: 1.6449 - val_accuracy: 0.4228
# Epoch 9/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.5712 - accuracy: 0.4358 - val_loss: 1.4903 - val_accuracy: 0.4855
# Epoch 10/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.4219 - accuracy: 0.4950 - val_loss: 1.6552 - val_accuracy: 0.4362
# Epoch 11/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.3239 - accuracy: 0.5251 - val_loss: 1.4597 - val_accuracy: 0.4989
# Epoch 12/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.2687 - accuracy: 0.5430 - val_loss: 1.5745 - val_accuracy: 0.5101
# Epoch 13/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.2318 - accuracy: 0.5575 - val_loss: 1.6012 - val_accuracy: 0.5347
# Epoch 14/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.1118 - accuracy: 0.6177 - val_loss: 1.6720 - val_accuracy: 0.5168
# Epoch 15/20
# 56/56 [==============================] - 5s 94ms/step - loss: 1.0678 - accuracy: 0.6244 - val_loss: 1.8131 - val_accuracy: 0.5056
# Epoch 16/20
# 56/56 [==============================] - 5s 94ms/step - loss: 0.9543 - accuracy: 0.6635 - val_loss: 1.8600 - val_accuracy: 0.4743
# Epoch 17/20
# 56/56 [==============================] - 5s 94ms/step - loss: 0.9270 - accuracy: 0.6786 - val_loss: 2.3223 - val_accuracy: 0.4832
# Epoch 18/20
# 56/56 [==============================] - 5s 94ms/step - loss: 0.8661 - accuracy: 0.6959 - val_loss: 2.1529 - val_accuracy: 0.4765
# Epoch 19/20
# 56/56 [==============================] - 5s 94ms/step - loss: 0.7159 - accuracy: 0.7506 - val_loss: 2.7211 - val_accuracy: 0.4564
# Epoch 20/20
# 56/56 [==============================] - 5s 94ms/step - loss: 0.6365 - accuracy: 0.7695 - val_loss: 3.0236 - val_accuracy: 0.4609
# CPU times: user 1min 30s, sys: 2.26 s, total: 1min 32s
# Wall time: 1min 50s

# %% [markdown]
# ### Visualizing training results

# %%
def visualizeResults(history, train_epochs):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(train_epochs)

    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()
    return acc, val_acc
acc1, val_acc1 = visualizeResults(history1, model1_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model1_epochs,max(acc1)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model1_epochs,max(val_acc1)*100))
# Out:
# Train Accuracy after 20 epochs: 76.95
# Validation Accuracy after 20 epochs: 53.47

# %% [markdown]
# ### Findings
#
# - Observing above graphs we can conclude that model ***Overfits*** to some degree, as the training accuracy is about ***77%*** and validation accuracy is approximately ***53.5%***.
# - Also after ***13*** epochs the ***validation accuracy started dropping*** and the ***validation loss has increased*** significantly.
# - It could be due to class imbalance or model is just learning noise. We need to add more data for it to generalise better. We might also use dropout to prevent noise leaking into model.

# %% [markdown]
# ## 5. Data Augmentation
#
# - As the model is overfitting, we will use data augmentation strategy to generate more data to improve the model performance as mentioned in findings of Model 1.
# - Since the classification is not constrained by the lighting or orientation or size of the infected area following data augmentation strategies can used.
#     - Flips (Vertical and Horizontal)
#     - Rotation (Various degrees)
#     - Zooming
#     - Contrast variation
# - We will be using random transformations package for this.

# %%
augument_data = Sequential([
    RandomFlip('horizontal_and_vertical'),
    RandomRotation((-0.1, 0.1)), 
    RandomZoom(0.2),
    RandomContrast(0.05)])

# %% [markdown]
# #### Visualizing how our augmentation strategy works for one instance of training image

# %%
plt.figure(figsize=(16, 8))
for images, labels in train_ds.take(1):
    image = images[0]
    label = tf.keras.backend.get_value(labels[0])
    
    ax = plt.subplot(1, 2, 1)
    plt.imshow(image.numpy().astype('uint8'))
    plt.title("Actual Image: " + class_names[label])

    ax = plt.subplot(1, 2, 2)
    image_aug = augument_data(tf.cast(image, tf.float32))
    plt.imshow(image_aug.numpy().astype('uint8'))
    plt.title("Augmented Image: " + class_names[label])
    
    plt.show()
    break

# %% [markdown]
# ## 6. Model Building and Training - Model 2 - Base CNN Model with dropout and Data Augumentation
#
# ### Creating second CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Data Augumentation layer
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers, followed by a ***Maxpooling layer*** and a ***Dropout layer***
# - Each CNN layer is followed by ***Batch Normalization layer***
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %%
model2 = Sequential()

model2.add(Rescaling(1./255, input_shape = input_shape))

model2.add(augument_data)


model2.add(Conv2D(32, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(Conv2D(32, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Conv2D(64, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(Conv2D(64, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))


model2.add(Conv2D(128, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(Conv2D(128, 3, padding='same',  activation='relu'))
model2.add(BatchNormalization())
model2.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model2.add(Flatten())
model2.add(Dense(1000, activation='relu'))
model2.add(Dense(class_count, activation='softmax'))
# Out:
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model2.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  sequential_1 (Sequential)   (180, 180, 3)             0
#
#  conv2d_6 (Conv2D)           (None, 180, 180, 32)      896
#
#  batch_normalization (BatchN  (None, 180, 180, 32)     128
#  ormalization)
#
#  conv2d_7 (Conv2D)           (None, 180, 180, 32)      9248
#
#  batch_normalization_1 (Batc  (None, 180, 180, 32)     128
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 90, 90, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 90, 90, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 90, 90, 64)       256
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 90, 90, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 90, 90, 64)       256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 45, 45, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 45, 45, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 45, 45, 128)      512
#  hNormalization)
#
#  conv2d_11 (Conv2D)          (None, 45, 45, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 45, 45, 128)      512
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 128)       0
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_2 (Dense)             (None, 1000)              61953000
#
#  dense_3 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 62,250,809
# Trainable params: 62,249,913
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***20 epochs***

# %%
# %%time
model2_epochs = 20
history2 = model2.fit(train_ds,
                      validation_data=val_ds,
                      epochs=model2_epochs)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# 56/56 [==============================] - ETA: 0s - loss: 25.7921 - accuracy: 0.2963WARNING:tensorflow:Model was constructed with shape (180, 180, 3) for input KerasTensor(type_spec=TensorSpec(shape=(180, 180, 3), dtype=tf.float32, name='random_flip_input'), name='random_flip_input', description="created by layer 'random_flip_input'"), but it was called on an input with incompatible shape (None, 180, 180, 3).
# 56/56 [==============================] - 11s 170ms/step - loss: 25.7921 - accuracy: 0.2963 - val_loss: 46.6068 - val_accuracy: 0.1544
# Epoch 2/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.8362 - accuracy: 0.3560 - val_loss: 107.6425 - val_accuracy: 0.1499
# Epoch 3/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.5581 - accuracy: 0.4542 - val_loss: 132.8913 - val_accuracy: 0.1499
# Epoch 4/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.5315 - accuracy: 0.4526 - val_loss: 131.4520 - val_accuracy: 0.1499
# Epoch 5/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.4363 - accuracy: 0.5073 - val_loss: 119.3963 - val_accuracy: 0.1499
# Epoch 6/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.4117 - accuracy: 0.4900 - val_loss: 89.0215 - val_accuracy: 0.1477
# Epoch 7/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.3588 - accuracy: 0.5140 - val_loss: 54.3715 - val_accuracy: 0.1611
# Epoch 8/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.3926 - accuracy: 0.5061 - val_loss: 29.3036 - val_accuracy: 0.1969
# Epoch 9/20
# 56/56 [==============================] - 9s 158ms/step - loss: 1.3327 - accuracy: 0.5151 - val_loss: 10.8420 - val_accuracy: 0.2438
# Epoch 10/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.3205 - accuracy: 0.5419 - val_loss: 4.7056 - val_accuracy: 0.3535
# Epoch 11/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.3123 - accuracy: 0.5385 - val_loss: 2.2336 - val_accuracy: 0.4273
# Epoch 12/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.3102 - accuracy: 0.5340 - val_loss: 1.9107 - val_accuracy: 0.4251
# Epoch 13/20
# 56/56 [==============================] - 9s 158ms/step - loss: 1.2909 - accuracy: 0.5491 - val_loss: 1.4889 - val_accuracy: 0.5324
# Epoch 14/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2913 - accuracy: 0.5519 - val_loss: 1.6702 - val_accuracy: 0.5347
# Epoch 15/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2897 - accuracy: 0.5463 - val_loss: 1.5632 - val_accuracy: 0.4564
# Epoch 16/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2746 - accuracy: 0.5558 - val_loss: 1.5880 - val_accuracy: 0.4609
# Epoch 17/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2831 - accuracy: 0.5419 - val_loss: 1.5370 - val_accuracy: 0.4899
# Epoch 18/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2968 - accuracy: 0.5463 - val_loss: 1.7135 - val_accuracy: 0.4362
# Epoch 19/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2526 - accuracy: 0.5491 - val_loss: 1.6741 - val_accuracy: 0.4340
# Epoch 20/20
# 56/56 [==============================] - 9s 159ms/step - loss: 1.2498 - accuracy: 0.5564 - val_loss: 1.8594 - val_accuracy: 0.4541
# CPU times: user 4min 1s, sys: 20.9 s, total: 4min 22s
# Wall time: 3min

# %% [markdown]
# ### Visualizing the results

# %%
acc2, val_acc2 = visualizeResults(history2, model2_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model2_epochs,max(acc2)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model2_epochs,max(val_acc2)*100))
# Out:
# Train Accuracy after 20 epochs: 55.64
# Validation Accuracy after 20 epochs: 53.47

# %% [markdown]
# ### Findings
#
# - The training accuracy is about ***55.5%*** and validation accuracy is approximately ***53.5%*** indicating that dropouts and data augumentation has helped closing the gap and preventing overfits.
# - Also after ***13*** epochs the ***validation accuracy started dropping***.
# - While after ***9*** epochs the ***validation loss has decreased*** significantly.
# - Since training accuracy itself is very low that means its has started to underfit, hence adding more data should help in improving the model.

# %% [markdown]
# ## 7. Examine Class Distribution in Training data set
#
# Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
class_distribution = {}
for cls in class_names:
    path = pathlib.Path(os.path.join(train_folder_path, cls))
    count = len(list(path.glob('*.jpg')))
    class_distribution[cls]=count
print(class_distribution)

plt.figure(figsize=(15, 6))
plt.bar(list(class_distribution.keys()), list(class_distribution.values()))
plt.title("Class distribution in training data")
plt.xticks(rotation = 45, ha = 'right');
# Out:
# {'actinic keratosis': 114, 'basal cell carcinoma': 376, 'dermatofibroma': 95, 'melanoma': 438, 'nevus': 357, 'pigmented benign keratosis': 462, 'seborrheic keratosis': 77, 'squamous cell carcinoma': 181, 'vascular lesion': 139}

# %% [markdown]
# ### Findings
#
# - Class 6(seborrheic keratosis) have least samples of all i.e. 77
# - Class 5(pigmented benign keratosis) dominate in terms of proportionate number of samples  i.e. 462
# - Dataset is quite imbalanced

# %% [markdown]
# ## 8. Handling class imbalances
#
# - It is improtant to have class balance for better infering the performance of the model.
# - Having good amount of data, helps the model to learn the useful features and improve the prediction power of the model.
# - We will use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.
# - This will help us tackle the class imbalance issue and increase input data volume for better modelling.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in /home/jaskirat/miniconda3/lib/python3.8/site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.11.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (1.23.1)
# Requirement already satisfied: tqdm>=4.9.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (4.63.0)
# Requirement already satisfied: Pillow>=5.2.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (9.2.0)
# Requirement already satisfied: future>=0.16.0 in /home/jaskirat/miniconda3/lib/python3.8/site-packages (from Augmentor) (0.18.2)

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=train_folder_path
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + '/' + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE06C82BA60>: 100%|██████████| 500/500 [00:02<00:00, 220.56 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FE06C7D1580>: 100%|██████████| 500/500 [00:02<00:00, 226.84 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE06C7D6550>: 100%|██████████| 500/500 [00:02<00:00, 208.75 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDFF07E2730>: 100%|██████████| 500/500 [00:11<00:00, 43.16 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FDFF07A4970>: 100%|██████████| 500/500 [00:14<00:00, 34.70 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDFF07F8B20>: 100%|██████████| 500/500 [00:02<00:00, 203.50 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDFF0055460>: 100%|██████████| 500/500 [00:05<00:00, 91.03 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FE06C8A2730>: 100%|██████████| 500/500 [00:02<00:00, 210.05 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDFD0285E50>: 100%|██████████| 500/500 [00:02<00:00, 208.65 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
## path of individual images from new data

path_list_new = [x for x in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
len(path_list_new)
# Out:
# 4500

# %%
## classnames for individual images from new data

lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
len(lesion_list_new)
# Out:
# 4500

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
new_df = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])

# %%
new_df['Label'].value_counts()
# Out:
# squamous cell carcinoma       500
# pigmented benign keratosis    500
# nevus                         500
# vascular lesion               500
# melanoma                      500
# actinic keratosis             500
# seborrheic keratosis          500
# dermatofibroma                500
# basal cell carcinoma          500
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# ## 9. Model Building and Training - Model 3 - Base CNN Model with Balanced Class Data

# %% [markdown]
# ### Creating augmented training dataset

# %%
train_ds_aug = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=seed,
  validation_split = validation_split,
  subset = "training",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### Creating augumented validation dataset

# %%
val_ds_aug = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=seed,
  validation_split = validation_split,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ### Creating third CNN model, which aims to accurately detect 9 classes present in the dataset.
#
# #### Model definition
#
# - Rescaling of input values between 0 and 1 (as RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network.)
# - Data Augumentation layer
# - Shallow CNN network with ***3 CNN*** blocks and ***2 Fully Connected(FC)*** layers
# - Each CNN block has ***2 CNN*** layers, followed by a ***Maxpooling layer*** and a ***Dropout layer***
# - Each CNN layer is followed by ***Batch Normalization layer***
# - ***Relu*** activation is used in CNN layers
# - ***Softmax*** function is used at the last FC layer

# %%
model3 = Sequential()

model3.add(Rescaling(1./255, input_shape = input_shape))

model3.add(Conv2D(32, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(32, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model3.add(Conv2D(64, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(64, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model3.add(Conv2D(128, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(Conv2D(128, 3, padding='same',  activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPool2D(2,2))
model2.add(Dropout(0.25))

model3.add(Flatten())
model3.add(Dense(1000, activation='relu'))
model3.add(Dense(class_count, activation='softmax'))

# %% [markdown]
# ### Compiling the model
#
# Choosing an appropirate optimiser and loss function for model training
#
# - ***Adam*** optimizer is used for ***optimizer*** setting
# - ***Sparse Categorical CrossEntropy*** is used as ***loss function*** since its multi-class classification problem
# - ***Accuracy*** is used as the ***performance*** metrics

# %%
model3.compile(optimizer='adam',
              loss=losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
# View the summary of all layers
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 180, 180, 32)      896
#
#  batch_normalization_6 (Batc  (None, 180, 180, 32)     128
#  hNormalization)
#
#  conv2d_13 (Conv2D)          (None, 180, 180, 32)      9248
#
#  batch_normalization_7 (Batc  (None, 180, 180, 32)     128
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 90, 90, 64)        18496
#
#  batch_normalization_8 (Batc  (None, 90, 90, 64)       256
#  hNormalization)
#
#  conv2d_15 (Conv2D)          (None, 90, 90, 64)        36928
#
#  batch_normalization_9 (Batc  (None, 90, 90, 64)       256
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 45, 45, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 45, 45, 128)      512
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 45, 45, 128)       147584
#
#  batch_normalization_11 (Bat  (None, 45, 45, 128)      512
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 22, 22, 128)      0
#  2D)
#
#  flatten_2 (Flatten)         (None, 61952)             0
#
#  dense_4 (Dense)             (None, 1000)              61953000
#
#  dense_5 (Dense)             (None, 9)                 9009
#
# =================================================================
# Total params: 62,250,809
# Trainable params: 62,249,913
# Non-trainable params: 896
# _________________________________________________________________

# %% [markdown]
# ### Training the model
#
# Training for ***30 epochs***

# %%
# %%time
model3_epochs = 30
history3 = model3.fit(train_ds_aug,
                      validation_data=val_ds_aug,
                      epochs=model3_epochs)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 22s 124ms/step - loss: 6.9789 - accuracy: 0.3229 - val_loss: 48.6023 - val_accuracy: 0.1314
# Epoch 2/30
# 169/169 [==============================] - 21s 120ms/step - loss: 1.4103 - accuracy: 0.4718 - val_loss: 32.0981 - val_accuracy: 0.1997
# Epoch 3/30
# 169/169 [==============================] - 21s 120ms/step - loss: 1.1562 - accuracy: 0.5651 - val_loss: 4.6988 - val_accuracy: 0.3348
# Epoch 4/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.9575 - accuracy: 0.6376 - val_loss: 1.1968 - val_accuracy: 0.5798
# Epoch 5/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.7971 - accuracy: 0.6988 - val_loss: 1.2545 - val_accuracy: 0.6125
# Epoch 6/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.7587 - accuracy: 0.7292 - val_loss: 1.6398 - val_accuracy: 0.5219
# Epoch 7/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.6084 - accuracy: 0.7685 - val_loss: 0.9226 - val_accuracy: 0.7097
# Epoch 8/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.5035 - accuracy: 0.8077 - val_loss: 0.9603 - val_accuracy: 0.6971
# Epoch 9/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.4485 - accuracy: 0.8342 - val_loss: 1.0109 - val_accuracy: 0.7023
# Epoch 10/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.4058 - accuracy: 0.8490 - val_loss: 1.1209 - val_accuracy: 0.6748
# Epoch 11/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.3349 - accuracy: 0.8769 - val_loss: 0.9144 - val_accuracy: 0.7298
# Epoch 12/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.3555 - accuracy: 0.8696 - val_loss: 2.6462 - val_accuracy: 0.5056
# Epoch 13/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.3567 - accuracy: 0.8589 - val_loss: 11.3761 - val_accuracy: 0.1819
# Epoch 14/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.2929 - accuracy: 0.8924 - val_loss: 1.4984 - val_accuracy: 0.6540
# Epoch 15/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.2775 - accuracy: 0.9021 - val_loss: 1.2428 - val_accuracy: 0.7105
# Epoch 16/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.2977 - accuracy: 0.8984 - val_loss: 16.6969 - val_accuracy: 0.2494
# Epoch 17/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.3898 - accuracy: 0.8676 - val_loss: 1.3557 - val_accuracy: 0.6407
# Epoch 18/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.2456 - accuracy: 0.9102 - val_loss: 1.8232 - val_accuracy: 0.6043
# Epoch 19/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.2110 - accuracy: 0.9165 - val_loss: 14.1730 - val_accuracy: 0.2561
# Epoch 20/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.3068 - accuracy: 0.8974 - val_loss: 1.4024 - val_accuracy: 0.7016
# Epoch 21/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1956 - accuracy: 0.9314 - val_loss: 1.1243 - val_accuracy: 0.7298
# Epoch 22/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1661 - accuracy: 0.9338 - val_loss: 1.9868 - val_accuracy: 0.6266
# Epoch 23/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.2144 - accuracy: 0.9238 - val_loss: 1.1744 - val_accuracy: 0.7387
# Epoch 24/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.2003 - accuracy: 0.9306 - val_loss: 1.1889 - val_accuracy: 0.7758
# Epoch 25/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1637 - accuracy: 0.9397 - val_loss: 3.0523 - val_accuracy: 0.5189
# Epoch 26/30
# 169/169 [==============================] - 21s 120ms/step - loss: 0.1538 - accuracy: 0.9410 - val_loss: 1.0163 - val_accuracy: 0.8144
# Epoch 27/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.1445 - accuracy: 0.9405 - val_loss: 1.7781 - val_accuracy: 0.6407
# Epoch 28/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.1367 - accuracy: 0.9444 - val_loss: 1.1595 - val_accuracy: 0.8062
# Epoch 29/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.1877 - accuracy: 0.9312 - val_loss: 1.5669 - val_accuracy: 0.7290
# Epoch 30/30
# 169/169 [==============================] - 21s 121ms/step - loss: 0.2079 - accuracy: 0.9310 - val_loss: 2.7131 - val_accuracy: 0.5546
# CPU times: user 19min 22s, sys: 24 s, total: 19min 46s
# Wall time: 10min 20s

# %% [markdown]
# ### Visualizing the results

# %%
acc3, val_acc3 = visualizeResults(history3, model3_epochs)

# %%
print("\033[1mTrain Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model3_epochs,max(acc3)*100))
print("\033[1mValidation Accuracy\033[0m after {0} epochs: \033[1m{1:.2f}\033[0m".format(model3_epochs,max(val_acc3)*100))
# Out:
# Train Accuracy after 30 epochs: 94.44
# Validation Accuracy after 30 epochs: 81.44

# %% [markdown]
# ### Findings
#
# - Observing above graphs we can conclude that model ***Overfits*** to some degree, as the training accuracy is about ***94%*** and validation accuracy is approximately ***81%***.
# - While we ended up ***increasing training and validation accuracy*** to ***decent levels*** with more data, class balance and  more epochs, it certainly still overfits as there is significant difference between both of them
# - We can add more data and layers to further improve the performance
